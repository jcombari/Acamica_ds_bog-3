# %% [markdown]
# # Redes Neuronales
#
# En este notebook vamos a construir la unidad básica de las redes neuronales, el Perceptrón. Tiene dos partes:
# 1. **Perceptrón 2D**: vamos a entrenar un Perceptrón con Keras sobre un dataset ficticio. Exploramos cómo son las fronteras en 2D. Limitaciones del Perceptrón. Generamos un dataset no-linealmente separable y vemos cómo responde el Perceptrón.
# 2. **MNIST**: vamos a trabajar con este conocido dataset. El objetivo es identificar dígitos, del 0 al 9, escritos a manos. Primero entrenaremos una red neuronal de una capa y luego una Red Neuronal de más capas.
#
# ## 1. Perceptrón en 2D
#
# Vamos a generar un dataset sintético con unas funciones que ya vienen incorporadas en scikit-learn.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
from sklearn.datasets.samples_generator import make_blobs, make_moons
X, y = make_blobs(n_samples=1000, centers=2, n_features=2,
                  random_state=0)

X, y = make_moons(n_samples=1000, random_state=0)

# %%
print(X.shape)
print(y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Reescalamos los datos

# %%
X[:,0] = (X[:,0] - X[:,0].mean())/X[:,0].std()
X[:,1] = (X[:,1] - X[:,1].mean())/X[:,1].std()

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Definimos el modelo a entrenar y volvemos a mirar algunas de sus características.

# %%
model = Sequential()
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X, y, epochs=250, validation_split=0.25)
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/250
# 750/750 [==============================] - 2s 2ms/step - loss: 1.0337 - acc: 0.2507 - val_loss: 0.9840 - val_acc: 0.2280
# Epoch 2/250
# 750/750 [==============================] - 0s 133us/step - loss: 0.9393 - acc: 0.2587 - val_loss: 0.8917 - val_acc: 0.2280
# Epoch 3/250
# 750/750 [==============================] - 0s 133us/step - loss: 0.8507 - acc: 0.2600 - val_loss: 0.8098 - val_acc: 0.2280
# Epoch 4/250
# 750/750 [==============================] - 0s 138us/step - loss: 0.7730 - acc: 0.2933 - val_loss: 0.7371 - val_acc: 0.3480
# Epoch 5/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.7033 - acc: 0.4307 - val_loss: 0.6727 - val_acc: 0.5040
# Epoch 6/250
# 750/750 [==============================] - 0s 132us/step - loss: 0.6424 - acc: 0.6173 - val_loss: 0.6159 - val_acc: 0.7000
# Epoch 7/250
# 750/750 [==============================] - 0s 132us/step - loss: 0.5880 - acc: 0.7320 - val_loss: 0.5658 - val_acc: 0.7280
# Epoch 8/250
# 750/750 [==============================] - 0s 150us/step - loss: 0.5409 - acc: 0.7480 - val_loss: 0.5220 - val_acc: 0.7560
# Epoch 9/250
# 750/750 [==============================] - 0s 142us/step - loss: 0.4985 - acc: 0.7640 - val_loss: 0.4819 - val_acc: 0.7760
# Epoch 10/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.4616 - acc: 0.7827 - val_loss: 0.4472 - val_acc: 0.7960
# Epoch 11/250
# 750/750 [==============================] - 0s 132us/step - loss: 0.4308 - acc: 0.8187 - val_loss: 0.4176 - val_acc: 0.8120
# Epoch 12/250
# 750/750 [==============================] - 0s 146us/step - loss: 0.4034 - acc: 0.8307 - val_loss: 0.3907 - val_acc: 0.8400
# Epoch 13/250
# 750/750 [==============================] - 0s 144us/step - loss: 0.3786 - acc: 0.8480 - val_loss: 0.3670 - val_acc: 0.8520
# Epoch 14/250
# 750/750 [==============================] - 0s 132us/step - loss: 0.3577 - acc: 0.8533 - val_loss: 0.3446 - val_acc: 0.8640
# Epoch 15/250
# 750/750 [==============================] - 0s 132us/step - loss: 0.3377 - acc: 0.8613 - val_loss: 0.3246 - val_acc: 0.8680
# Epoch 16/250
# 750/750 [==============================] - 0s 140us/step - loss: 0.3207 - acc: 0.8693 - val_loss: 0.3064 - val_acc: 0.8760
# Epoch 17/250
# 750/750 [==============================] - 0s 140us/step - loss: 0.3054 - acc: 0.8747 - val_loss: 0.2906 - val_acc: 0.8720
# Epoch 18/250
# 750/750 [==============================] - 0s 140us/step - loss: 0.2927 - acc: 0.8800 - val_loss: 0.2767 - val_acc: 0.8800
# Epoch 19/250
# 750/750 [==============================] - 0s 146us/step - loss: 0.2809 - acc: 0.8853 - val_loss: 0.2629 - val_acc: 0.8840
# Epoch 20/250
# 750/750 [==============================] - 0s 139us/step - loss: 0.2701 - acc: 0.8880 - val_loss: 0.2511 - val_acc: 0.8920
# Epoch 21/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.2612 - acc: 0.8920 - val_loss: 0.2410 - val_acc: 0.8920
# Epoch 22/250
# 750/750 [==============================] - 0s 140us/step - loss: 0.2536 - acc: 0.8960 - val_loss: 0.2323 - val_acc: 0.8960
# Epoch 23/250
# 750/750 [==============================] - 0s 144us/step - loss: 0.2465 - acc: 0.8973 - val_loss: 0.2234 - val_acc: 0.9000
# Epoch 24/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.2406 - acc: 0.8987 - val_loss: 0.2169 - val_acc: 0.9080
# Epoch 25/250
# 750/750 [==============================] - 0s 137us/step - loss: 0.2353 - acc: 0.8987 - val_loss: 0.2102 - val_acc: 0.9160
# Epoch 26/250
# 750/750 [==============================] - 0s 127us/step - loss: 0.2303 - acc: 0.9000 - val_loss: 0.2050 - val_acc: 0.9160
# Epoch 27/250
# 750/750 [==============================] - 0s 152us/step - loss: 0.2262 - acc: 0.9040 - val_loss: 0.1998 - val_acc: 0.9160
# Epoch 28/250
# 750/750 [==============================] - 0s 136us/step - loss: 0.2223 - acc: 0.9040 - val_loss: 0.1957 - val_acc: 0.9160
# Epoch 29/250
# 750/750 [==============================] - 0s 145us/step - loss: 0.2190 - acc: 0.9067 - val_loss: 0.1914 - val_acc: 0.9240
# Epoch 30/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.2157 - acc: 0.9067 - val_loss: 0.1879 - val_acc: 0.9240
# Epoch 31/250
# 750/750 [==============================] - 0s 132us/step - loss: 0.2127 - acc: 0.9067 - val_loss: 0.1845 - val_acc: 0.9280
# Epoch 32/250
# 750/750 [==============================] - 0s 149us/step - loss: 0.2093 - acc: 0.9107 - val_loss: 0.1811 - val_acc: 0.9280
# Epoch 33/250
# 750/750 [==============================] - 0s 150us/step - loss: 0.2062 - acc: 0.9107 - val_loss: 0.1775 - val_acc: 0.9280
# Epoch 34/250
# 750/750 [==============================] - 0s 138us/step - loss: 0.2028 - acc: 0.9120 - val_loss: 0.1742 - val_acc: 0.9320
# Epoch 35/250
# 750/750 [==============================] - 0s 126us/step - loss: 0.2003 - acc: 0.9120 - val_loss: 0.1716 - val_acc: 0.9320
# Epoch 36/250
# 750/750 [==============================] - 0s 141us/step - loss: 0.1976 - acc: 0.9133 - val_loss: 0.1687 - val_acc: 0.9360
# Epoch 37/250
# 750/750 [==============================] - 0s 172us/step - loss: 0.1948 - acc: 0.9147 - val_loss: 0.1656 - val_acc: 0.9360
# Epoch 38/250
# 750/750 [==============================] - 0s 154us/step - loss: 0.1922 - acc: 0.9160 - val_loss: 0.1634 - val_acc: 0.9360
# Epoch 39/250
# 750/750 [==============================] - 0s 151us/step - loss: 0.1894 - acc: 0.9160 - val_loss: 0.1604 - val_acc: 0.9400
# Epoch 40/250
# 750/750 [==============================] - 0s 155us/step - loss: 0.1870 - acc: 0.9160 - val_loss: 0.1584 - val_acc: 0.9400
# Epoch 41/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.1848 - acc: 0.9160 - val_loss: 0.1561 - val_acc: 0.9400
# Epoch 42/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.1819 - acc: 0.9187 - val_loss: 0.1534 - val_acc: 0.9400
# Epoch 43/250
# 750/750 [==============================] - 0s 141us/step - loss: 0.1794 - acc: 0.9200 - val_loss: 0.1513 - val_acc: 0.9400
# Epoch 44/250
# 750/750 [==============================] - 0s 137us/step - loss: 0.1771 - acc: 0.9213 - val_loss: 0.1492 - val_acc: 0.9400
# Epoch 45/250
# 750/750 [==============================] - 0s 136us/step - loss: 0.1745 - acc: 0.9227 - val_loss: 0.1471 - val_acc: 0.9400
# Epoch 46/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.1721 - acc: 0.9240 - val_loss: 0.1449 - val_acc: 0.9400
# Epoch 47/250
# 750/750 [==============================] - 0s 125us/step - loss: 0.1696 - acc: 0.9240 - val_loss: 0.1423 - val_acc: 0.9440
# Epoch 48/250
# 750/750 [==============================] - 0s 124us/step - loss: 0.1668 - acc: 0.9267 - val_loss: 0.1398 - val_acc: 0.9440
# Epoch 49/250
# 750/750 [==============================] - 0s 126us/step - loss: 0.1641 - acc: 0.9280 - val_loss: 0.1372 - val_acc: 0.9480
# Epoch 50/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.1618 - acc: 0.9267 - val_loss: 0.1351 - val_acc: 0.9480
# Epoch 51/250
# 750/750 [==============================] - 0s 126us/step - loss: 0.1591 - acc: 0.9293 - val_loss: 0.1328 - val_acc: 0.9480
# Epoch 52/250
# 750/750 [==============================] - 0s 159us/step - loss: 0.1565 - acc: 0.9307 - val_loss: 0.1310 - val_acc: 0.9480
# Epoch 53/250
# 750/750 [==============================] - 0s 157us/step - loss: 0.1539 - acc: 0.9307 - val_loss: 0.1282 - val_acc: 0.9520
# Epoch 54/250
# 750/750 [==============================] - 0s 180us/step - loss: 0.1514 - acc: 0.9320 - val_loss: 0.1260 - val_acc: 0.9520
# Epoch 55/250
# 750/750 [==============================] - 0s 189us/step - loss: 0.1489 - acc: 0.9333 - val_loss: 0.1237 - val_acc: 0.9520
# Epoch 56/250
# 750/750 [==============================] - 0s 169us/step - loss: 0.1463 - acc: 0.9360 - val_loss: 0.1212 - val_acc: 0.9560
# Epoch 57/250
# 750/750 [==============================] - 0s 152us/step - loss: 0.1439 - acc: 0.9360 - val_loss: 0.1189 - val_acc: 0.9600
# Epoch 58/250
# 750/750 [==============================] - 0s 141us/step - loss: 0.1413 - acc: 0.9373 - val_loss: 0.1171 - val_acc: 0.9600
# Epoch 59/250
# 750/750 [==============================] - 0s 154us/step - loss: 0.1389 - acc: 0.9387 - val_loss: 0.1152 - val_acc: 0.9640
# Epoch 60/250
# 750/750 [==============================] - 0s 153us/step - loss: 0.1368 - acc: 0.9387 - val_loss: 0.1131 - val_acc: 0.9640
# Epoch 61/250
# 750/750 [==============================] - 0s 121us/step - loss: 0.1342 - acc: 0.9387 - val_loss: 0.1111 - val_acc: 0.9640
# Epoch 62/250
# 750/750 [==============================] - 0s 120us/step - loss: 0.1316 - acc: 0.9413 - val_loss: 0.1087 - val_acc: 0.9640
# Epoch 63/250
# 750/750 [==============================] - 0s 150us/step - loss: 0.1293 - acc: 0.9427 - val_loss: 0.1066 - val_acc: 0.9640
# Epoch 64/250
# 750/750 [==============================] - 0s 200us/step - loss: 0.1268 - acc: 0.9453 - val_loss: 0.1042 - val_acc: 0.9640
# Epoch 65/250
# 750/750 [==============================] - 0s 152us/step - loss: 0.1244 - acc: 0.9467 - val_loss: 0.1021 - val_acc: 0.9680
# Epoch 66/250
# 750/750 [==============================] - 0s 121us/step - loss: 0.1219 - acc: 0.9467 - val_loss: 0.1004 - val_acc: 0.9720
# Epoch 67/250
# 750/750 [==============================] - 0s 117us/step - loss: 0.1195 - acc: 0.9493 - val_loss: 0.0983 - val_acc: 0.9720
# Epoch 68/250
# 750/750 [==============================] - 0s 114us/step - loss: 0.1173 - acc: 0.9507 - val_loss: 0.0968 - val_acc: 0.9720
# Epoch 69/250
# 750/750 [==============================] - 0s 124us/step - loss: 0.1151 - acc: 0.9493 - val_loss: 0.0946 - val_acc: 0.9720
# Epoch 70/250
# 750/750 [==============================] - 0s 122us/step - loss: 0.1127 - acc: 0.9520 - val_loss: 0.0923 - val_acc: 0.9720
# Epoch 71/250
# 750/750 [==============================] - 0s 118us/step - loss: 0.1109 - acc: 0.9533 - val_loss: 0.0907 - val_acc: 0.9760
# Epoch 72/250
# 750/750 [==============================] - 0s 152us/step - loss: 0.1087 - acc: 0.9547 - val_loss: 0.0889 - val_acc: 0.9760
# Epoch 73/250
# 750/750 [==============================] - 0s 151us/step - loss: 0.1069 - acc: 0.9547 - val_loss: 0.0870 - val_acc: 0.9760
# Epoch 74/250
# 750/750 [==============================] - 0s 147us/step - loss: 0.1044 - acc: 0.9600 - val_loss: 0.0850 - val_acc: 0.9760
# Epoch 75/250
# 750/750 [==============================] - 0s 144us/step - loss: 0.1021 - acc: 0.9587 - val_loss: 0.0829 - val_acc: 0.9760
# Epoch 76/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0998 - acc: 0.9613 - val_loss: 0.0807 - val_acc: 0.9760
# Epoch 77/250
# 750/750 [==============================] - 0s 119us/step - loss: 0.0978 - acc: 0.9627 - val_loss: 0.0789 - val_acc: 0.9800
# Epoch 78/250
# 750/750 [==============================] - 0s 125us/step - loss: 0.0955 - acc: 0.9640 - val_loss: 0.0770 - val_acc: 0.9800
# Epoch 79/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.0937 - acc: 0.9640 - val_loss: 0.0754 - val_acc: 0.9800
# Epoch 80/250
# 750/750 [==============================] - 0s 167us/step - loss: 0.0916 - acc: 0.9667 - val_loss: 0.0738 - val_acc: 0.9840
# Epoch 81/250
# 750/750 [==============================] - 0s 180us/step - loss: 0.0895 - acc: 0.9693 - val_loss: 0.0720 - val_acc: 0.9840
# Epoch 82/250
# 750/750 [==============================] - 0s 138us/step - loss: 0.0877 - acc: 0.9693 - val_loss: 0.0705 - val_acc: 0.9840
# Epoch 83/250
# 750/750 [==============================] - 0s 157us/step - loss: 0.0858 - acc: 0.9720 - val_loss: 0.0687 - val_acc: 0.9840
# Epoch 84/250
# 750/750 [==============================] - 0s 142us/step - loss: 0.0837 - acc: 0.9733 - val_loss: 0.0672 - val_acc: 0.9840
# Epoch 85/250
# 750/750 [==============================] - 0s 163us/step - loss: 0.0818 - acc: 0.9760 - val_loss: 0.0656 - val_acc: 0.9840
# Epoch 86/250
# 750/750 [==============================] - 0s 161us/step - loss: 0.0799 - acc: 0.9773 - val_loss: 0.0642 - val_acc: 0.9880
# Epoch 87/250
# 750/750 [==============================] - 0s 151us/step - loss: 0.0781 - acc: 0.9760 - val_loss: 0.0623 - val_acc: 0.9880
# Epoch 88/250
# 750/750 [==============================] - 0s 169us/step - loss: 0.0761 - acc: 0.9800 - val_loss: 0.0608 - val_acc: 0.9880
# Epoch 89/250
# 750/750 [==============================] - 0s 140us/step - loss: 0.0742 - acc: 0.9827 - val_loss: 0.0592 - val_acc: 0.9880
# Epoch 90/250
# 750/750 [==============================] - 0s 153us/step - loss: 0.0723 - acc: 0.9827 - val_loss: 0.0577 - val_acc: 0.9880
# Epoch 91/250
# 750/750 [==============================] - 0s 145us/step - loss: 0.0705 - acc: 0.9840 - val_loss: 0.0564 - val_acc: 0.9920
# Epoch 92/250
# 750/750 [==============================] - 0s 132us/step - loss: 0.0691 - acc: 0.9840 - val_loss: 0.0547 - val_acc: 0.9920
# Epoch 93/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0671 - acc: 0.9867 - val_loss: 0.0533 - val_acc: 0.9920
# Epoch 94/250
# 750/750 [==============================] - 0s 118us/step - loss: 0.0654 - acc: 0.9880 - val_loss: 0.0518 - val_acc: 0.9960
# Epoch 95/250
# 750/750 [==============================] - 0s 149us/step - loss: 0.0635 - acc: 0.9880 - val_loss: 0.0501 - val_acc: 0.9960
# Epoch 96/250
# 750/750 [==============================] - 0s 178us/step - loss: 0.0619 - acc: 0.9880 - val_loss: 0.0489 - val_acc: 0.9960
# Epoch 97/250
# 750/750 [==============================] - 0s 146us/step - loss: 0.0605 - acc: 0.9893 - val_loss: 0.0479 - val_acc: 0.9960
# Epoch 98/250
# 750/750 [==============================] - 0s 137us/step - loss: 0.0590 - acc: 0.9893 - val_loss: 0.0465 - val_acc: 0.9960
# Epoch 99/250
# 750/750 [==============================] - 0s 146us/step - loss: 0.0576 - acc: 0.9907 - val_loss: 0.0452 - val_acc: 0.9960
# Epoch 100/250
# 750/750 [==============================] - 0s 143us/step - loss: 0.0561 - acc: 0.9907 - val_loss: 0.0439 - val_acc: 1.0000
# Epoch 101/250
# 750/750 [==============================] - 0s 143us/step - loss: 0.0545 - acc: 0.9907 - val_loss: 0.0428 - val_acc: 1.0000
# Epoch 102/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0532 - acc: 0.9920 - val_loss: 0.0415 - val_acc: 1.0000
# Epoch 103/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0518 - acc: 0.9920 - val_loss: 0.0403 - val_acc: 1.0000
# Epoch 104/250
# 750/750 [==============================] - 0s 126us/step - loss: 0.0501 - acc: 0.9933 - val_loss: 0.0391 - val_acc: 1.0000
# Epoch 105/250
# 750/750 [==============================] - 0s 138us/step - loss: 0.0489 - acc: 0.9947 - val_loss: 0.0378 - val_acc: 1.0000
# Epoch 106/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0472 - acc: 0.9947 - val_loss: 0.0368 - val_acc: 1.0000
# Epoch 107/250
# 750/750 [==============================] - 0s 136us/step - loss: 0.0461 - acc: 0.9947 - val_loss: 0.0360 - val_acc: 1.0000
# Epoch 108/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0448 - acc: 0.9947 - val_loss: 0.0346 - val_acc: 1.0000
# Epoch 109/250
# 750/750 [==============================] - 0s 123us/step - loss: 0.0437 - acc: 0.9973 - val_loss: 0.0336 - val_acc: 1.0000
# Epoch 110/250
# 750/750 [==============================] - 0s 116us/step - loss: 0.0422 - acc: 0.9973 - val_loss: 0.0325 - val_acc: 1.0000
# Epoch 111/250
# 750/750 [==============================] - 0s 122us/step - loss: 0.0412 - acc: 0.9987 - val_loss: 0.0316 - val_acc: 1.0000
# Epoch 112/250
# 750/750 [==============================] - 0s 118us/step - loss: 0.0399 - acc: 0.9987 - val_loss: 0.0309 - val_acc: 1.0000
# Epoch 113/250
# 750/750 [==============================] - 0s 137us/step - loss: 0.0388 - acc: 1.0000 - val_loss: 0.0298 - val_acc: 1.0000
# Epoch 114/250
# 750/750 [==============================] - 0s 133us/step - loss: 0.0376 - acc: 1.0000 - val_loss: 0.0289 - val_acc: 1.0000
# Epoch 115/250
# 750/750 [==============================] - 0s 124us/step - loss: 0.0364 - acc: 1.0000 - val_loss: 0.0278 - val_acc: 1.0000
# Epoch 116/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.0352 - acc: 1.0000 - val_loss: 0.0270 - val_acc: 1.0000
# Epoch 117/250
# 750/750 [==============================] - 0s 161us/step - loss: 0.0343 - acc: 1.0000 - val_loss: 0.0260 - val_acc: 1.0000
# Epoch 118/250
# 750/750 [==============================] - 0s 144us/step - loss: 0.0332 - acc: 1.0000 - val_loss: 0.0253 - val_acc: 1.0000
# Epoch 119/250
# 750/750 [==============================] - 0s 138us/step - loss: 0.0322 - acc: 1.0000 - val_loss: 0.0244 - val_acc: 1.0000
# Epoch 120/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0310 - acc: 1.0000 - val_loss: 0.0236 - val_acc: 1.0000
# Epoch 121/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0301 - acc: 1.0000 - val_loss: 0.0228 - val_acc: 1.0000
# Epoch 122/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0293 - acc: 1.0000 - val_loss: 0.0222 - val_acc: 1.0000
# Epoch 123/250
# 750/750 [==============================] - 0s 136us/step - loss: 0.0286 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 1.0000
# Epoch 124/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0275 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 1.0000
# Epoch 125/250
# 750/750 [==============================] - 0s 143us/step - loss: 0.0267 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 1.0000
# Epoch 126/250
# 750/750 [==============================] - 0s 125us/step - loss: 0.0259 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 1.0000
# Epoch 127/250
# 750/750 [==============================] - 0s 114us/step - loss: 0.0253 - acc: 1.0000 - val_loss: 0.0190 - val_acc: 1.0000
# Epoch 128/250
# 750/750 [==============================] - 0s 113us/step - loss: 0.0247 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 1.0000
# Epoch 129/250
# 750/750 [==============================] - 0s 116us/step - loss: 0.0238 - acc: 1.0000 - val_loss: 0.0178 - val_acc: 1.0000
# Epoch 130/250
# 750/750 [==============================] - 0s 117us/step - loss: 0.0231 - acc: 1.0000 - val_loss: 0.0172 - val_acc: 1.0000
# Epoch 131/250
# 750/750 [==============================] - 0s 123us/step - loss: 0.0224 - acc: 1.0000 - val_loss: 0.0167 - val_acc: 1.0000
# Epoch 132/250
# 750/750 [==============================] - 0s 140us/step - loss: 0.0218 - acc: 1.0000 - val_loss: 0.0162 - val_acc: 1.0000
# Epoch 133/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.0212 - acc: 1.0000 - val_loss: 0.0157 - val_acc: 1.0000
# Epoch 134/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0206 - acc: 1.0000 - val_loss: 0.0152 - val_acc: 1.0000
# Epoch 135/250
# 750/750 [==============================] - 0s 153us/step - loss: 0.0199 - acc: 1.0000 - val_loss: 0.0146 - val_acc: 1.0000
# Epoch 136/250
# 750/750 [==============================] - 0s 173us/step - loss: 0.0194 - acc: 1.0000 - val_loss: 0.0142 - val_acc: 1.0000
# Epoch 137/250
# 750/750 [==============================] - 0s 147us/step - loss: 0.0188 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 1.0000
# Epoch 138/250
# 750/750 [==============================] - 0s 114us/step - loss: 0.0182 - acc: 1.0000 - val_loss: 0.0133 - val_acc: 1.0000
# Epoch 139/250
# 750/750 [==============================] - 0s 126us/step - loss: 0.0177 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 1.0000
# Epoch 140/250
# 750/750 [==============================] - 0s 143us/step - loss: 0.0172 - acc: 1.0000 - val_loss: 0.0125 - val_acc: 1.0000
# Epoch 141/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0165 - acc: 1.0000 - val_loss: 0.0121 - val_acc: 1.0000
# Epoch 142/250
# 750/750 [==============================] - 0s 126us/step - loss: 0.0162 - acc: 1.0000 - val_loss: 0.0117 - val_acc: 1.0000
# Epoch 143/250
# 750/750 [==============================] - 0s 110us/step - loss: 0.0157 - acc: 1.0000 - val_loss: 0.0112 - val_acc: 1.0000
# Epoch 144/250
# 750/750 [==============================] - 0s 119us/step - loss: 0.0151 - acc: 1.0000 - val_loss: 0.0109 - val_acc: 1.0000
# Epoch 145/250
# 750/750 [==============================] - 0s 110us/step - loss: 0.0147 - acc: 1.0000 - val_loss: 0.0106 - val_acc: 1.0000
# Epoch 146/250
# 750/750 [==============================] - 0s 112us/step - loss: 0.0142 - acc: 1.0000 - val_loss: 0.0102 - val_acc: 1.0000
# Epoch 147/250
# 750/750 [==============================] - 0s 123us/step - loss: 0.0137 - acc: 1.0000 - val_loss: 0.0099 - val_acc: 1.0000
# Epoch 148/250
# 750/750 [==============================] - 0s 129us/step - loss: 0.0136 - acc: 1.0000 - val_loss: 0.0095 - val_acc: 1.0000
# Epoch 149/250
# 750/750 [==============================] - 0s 110us/step - loss: 0.0129 - acc: 1.0000 - val_loss: 0.0092 - val_acc: 1.0000
# Epoch 150/250
# 750/750 [==============================] - 0s 135us/step - loss: 0.0125 - acc: 1.0000 - val_loss: 0.0089 - val_acc: 1.0000
# Epoch 151/250
# 750/750 [==============================] - 0s 139us/step - loss: 0.0121 - acc: 1.0000 - val_loss: 0.0087 - val_acc: 1.0000
# Epoch 152/250
# 750/750 [==============================] - 0s 142us/step - loss: 0.0118 - acc: 1.0000 - val_loss: 0.0085 - val_acc: 1.0000
# Epoch 153/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.0114 - acc: 1.0000 - val_loss: 0.0082 - val_acc: 1.0000
# Epoch 154/250
# 750/750 [==============================] - 0s 151us/step - loss: 0.0111 - acc: 1.0000 - val_loss: 0.0079 - val_acc: 1.0000
# Epoch 155/250
# 750/750 [==============================] - 0s 143us/step - loss: 0.0108 - acc: 1.0000 - val_loss: 0.0076 - val_acc: 1.0000
# Epoch 156/250
# 750/750 [==============================] - 0s 137us/step - loss: 0.0105 - acc: 1.0000 - val_loss: 0.0074 - val_acc: 1.0000
# Epoch 157/250
# 750/750 [==============================] - 0s 135us/step - loss: 0.0101 - acc: 1.0000 - val_loss: 0.0071 - val_acc: 1.0000
# Epoch 158/250
# 750/750 [==============================] - 0s 127us/step - loss: 0.0098 - acc: 1.0000 - val_loss: 0.0070 - val_acc: 1.0000
# Epoch 159/250
# 750/750 [==============================] - 0s 117us/step - loss: 0.0096 - acc: 1.0000 - val_loss: 0.0067 - val_acc: 1.0000
# Epoch 160/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.0094 - acc: 1.0000 - val_loss: 0.0065 - val_acc: 1.0000
# Epoch 161/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0091 - acc: 1.0000 - val_loss: 0.0063 - val_acc: 1.0000
# Epoch 162/250
# 750/750 [==============================] - 0s 161us/step - loss: 0.0087 - acc: 1.0000 - val_loss: 0.0061 - val_acc: 1.0000
# Epoch 163/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0083 - acc: 1.0000 - val_loss: 0.0059 - val_acc: 1.0000
# Epoch 164/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0083 - acc: 1.0000 - val_loss: 0.0057 - val_acc: 1.0000
# Epoch 165/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.0080 - acc: 1.0000 - val_loss: 0.0056 - val_acc: 1.0000
# Epoch 166/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.0078 - acc: 1.0000 - val_loss: 0.0054 - val_acc: 1.0000
# Epoch 167/250
# 750/750 [==============================] - 0s 143us/step - loss: 0.0075 - acc: 1.0000 - val_loss: 0.0052 - val_acc: 1.0000
# Epoch 168/250
# 750/750 [==============================] - 0s 137us/step - loss: 0.0073 - acc: 1.0000 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 169/250
# 750/750 [==============================] - 0s 121us/step - loss: 0.0070 - acc: 1.0000 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 170/250
# 750/750 [==============================] - 0s 110us/step - loss: 0.0068 - acc: 1.0000 - val_loss: 0.0046 - val_acc: 1.0000
# Epoch 171/250
# 750/750 [==============================] - 0s 112us/step - loss: 0.0067 - acc: 1.0000 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 172/250
# 750/750 [==============================] - 0s 109us/step - loss: 0.0067 - acc: 1.0000 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 173/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.0064 - acc: 1.0000 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 174/250
# 750/750 [==============================] - 0s 136us/step - loss: 0.0061 - acc: 1.0000 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 175/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0060 - acc: 1.0000 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 176/250
# 750/750 [==============================] - 0s 124us/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 177/250
# 750/750 [==============================] - 0s 123us/step - loss: 0.0056 - acc: 1.0000 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 178/250
# 750/750 [==============================] - 0s 133us/step - loss: 0.0055 - acc: 1.0000 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 179/250
# 750/750 [==============================] - 0s 155us/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 180/250
# 750/750 [==============================] - 0s 156us/step - loss: 0.0051 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 181/250
# 750/750 [==============================] - 0s 135us/step - loss: 0.0050 - acc: 1.0000 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 182/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 183/250
# 750/750 [==============================] - 0s 122us/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.0031 - val_acc: 1.0000
# Epoch 184/250
# 750/750 [==============================] - 0s 142us/step - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0030 - val_acc: 1.0000
# Epoch 185/250
# 750/750 [==============================] - 0s 203us/step - loss: 0.0045 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 186/250
# 750/750 [==============================] - 0s 148us/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 187/250
# 750/750 [==============================] - 0s 186us/step - loss: 0.0042 - acc: 1.0000 - val_loss: 0.0027 - val_acc: 1.0000
# Epoch 188/250
# 750/750 [==============================] - 0s 160us/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0026 - val_acc: 1.0000
# Epoch 189/250
# 750/750 [==============================] - 0s 221us/step - loss: 0.0040 - acc: 1.0000 - val_loss: 0.0026 - val_acc: 1.0000
# Epoch 190/250
# 750/750 [==============================] - 0s 178us/step - loss: 0.0039 - acc: 1.0000 - val_loss: 0.0025 - val_acc: 1.0000
# Epoch 191/250
# 750/750 [==============================] - 0s 137us/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 192/250
# 750/750 [==============================] - 0s 146us/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0023 - val_acc: 1.0000
# Epoch 193/250
# 750/750 [==============================] - 0s 163us/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0022 - val_acc: 1.0000
# Epoch 194/250
# 750/750 [==============================] - 0s 173us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0021 - val_acc: 1.0000
# Epoch 195/250
# 750/750 [==============================] - 0s 167us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0021 - val_acc: 1.0000
# Epoch 196/250
# 750/750 [==============================] - 0s 138us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0020 - val_acc: 1.0000
# Epoch 197/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0020 - val_acc: 1.0000
# Epoch 198/250
# 750/750 [==============================] - 0s 163us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 199/250
# 750/750 [==============================] - 0s 150us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 200/250
# 750/750 [==============================] - 0s 119us/step - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0018 - val_acc: 1.0000
# Epoch 201/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0017 - val_acc: 1.0000
# Epoch 202/250
# 750/750 [==============================] - 0s 123us/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0017 - val_acc: 1.0000
# Epoch 203/250
# 750/750 [==============================] - 0s 120us/step - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0016 - val_acc: 1.0000
# Epoch 204/250
# 750/750 [==============================] - 0s 112us/step - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0015 - val_acc: 1.0000
# Epoch 205/250
# 750/750 [==============================] - 0s 122us/step - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0015 - val_acc: 1.0000
# Epoch 206/250
# 750/750 [==============================] - 0s 151us/step - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0015 - val_acc: 1.0000
# Epoch 207/250
# 750/750 [==============================] - 0s 141us/step - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 1.0000
# Epoch 208/250
# 750/750 [==============================] - 0s 129us/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 1.0000
# Epoch 209/250
# 750/750 [==============================] - 0s 123us/step - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 1.0000
# Epoch 210/250
# 750/750 [==============================] - 0s 153us/step - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 1.0000
# Epoch 211/250
# 750/750 [==============================] - 0s 128us/step - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 1.0000
# Epoch 212/250
# 750/750 [==============================] - 0s 123us/step - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 1.0000
# Epoch 213/250
# 750/750 [==============================] - 0s 135us/step - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 1.0000
# Epoch 214/250
# 750/750 [==============================] - 0s 122us/step - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 215/250
# 750/750 [==============================] - 0s 152us/step - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 216/250
# 750/750 [==============================] - 0s 155us/step - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 217/250
# 750/750 [==============================] - 0s 165us/step - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0010 - val_acc: 1.0000
# Epoch 218/250
# 750/750 [==============================] - 0s 125us/step - loss: 0.0016 - acc: 1.0000 - val_loss: 9.9779e-04 - val_acc: 1.0000
# Epoch 219/250
# 750/750 [==============================] - 0s 138us/step - loss: 0.0016 - acc: 1.0000 - val_loss: 9.6003e-04 - val_acc: 1.0000
# Epoch 220/250
# 750/750 [==============================] - 0s 165us/step - loss: 0.0016 - acc: 1.0000 - val_loss: 9.1488e-04 - val_acc: 1.0000
# Epoch 221/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0015 - acc: 1.0000 - val_loss: 8.8833e-04 - val_acc: 1.0000
# Epoch 222/250
# 750/750 [==============================] - 0s 145us/step - loss: 0.0015 - acc: 1.0000 - val_loss: 8.6048e-04 - val_acc: 1.0000
# Epoch 223/250
# 750/750 [==============================] - 0s 129us/step - loss: 0.0014 - acc: 1.0000 - val_loss: 8.2918e-04 - val_acc: 1.0000
# Epoch 224/250
# 750/750 [==============================] - 0s 120us/step - loss: 0.0014 - acc: 1.0000 - val_loss: 8.0514e-04 - val_acc: 1.0000
# Epoch 225/250
# 750/750 [==============================] - 0s 124us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 7.8301e-04 - val_acc: 1.0000
# Epoch 226/250
# 750/750 [==============================] - 0s 142us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 7.6123e-04 - val_acc: 1.0000
# Epoch 227/250
# 750/750 [==============================] - 0s 136us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 7.3309e-04 - val_acc: 1.0000
# Epoch 228/250
# 750/750 [==============================] - 0s 137us/step - loss: 0.0012 - acc: 1.0000 - val_loss: 6.9715e-04 - val_acc: 1.0000
# Epoch 229/250
# 750/750 [==============================] - 0s 121us/step - loss: 0.0012 - acc: 1.0000 - val_loss: 6.7248e-04 - val_acc: 1.0000
# Epoch 230/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.0012 - acc: 1.0000 - val_loss: 6.4965e-04 - val_acc: 1.0000
# Epoch 231/250
# 750/750 [==============================] - 0s 129us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 6.3246e-04 - val_acc: 1.0000
# Epoch 232/250
# 750/750 [==============================] - 0s 123us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 6.0985e-04 - val_acc: 1.0000
# Epoch 233/250
# 750/750 [==============================] - 0s 116us/step - loss: 0.0010 - acc: 1.0000 - val_loss: 6.0726e-04 - val_acc: 1.0000
# Epoch 234/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.0010 - acc: 1.0000 - val_loss: 5.8013e-04 - val_acc: 1.0000
# Epoch 235/250
# 750/750 [==============================] - 0s 153us/step - loss: 9.8735e-04 - acc: 1.0000 - val_loss: 5.6290e-04 - val_acc: 1.0000
# Epoch 236/250
# 750/750 [==============================] - 0s 167us/step - loss: 9.7022e-04 - acc: 1.0000 - val_loss: 5.4383e-04 - val_acc: 1.0000
# Epoch 237/250
# 750/750 [==============================] - 0s 155us/step - loss: 9.9038e-04 - acc: 1.0000 - val_loss: 5.3084e-04 - val_acc: 1.0000
# Epoch 238/250
# 750/750 [==============================] - 0s 128us/step - loss: 9.4929e-04 - acc: 1.0000 - val_loss: 5.2312e-04 - val_acc: 1.0000
# Epoch 239/250
# 750/750 [==============================] - 0s 123us/step - loss: 9.4294e-04 - acc: 1.0000 - val_loss: 5.0196e-04 - val_acc: 1.0000
# Epoch 240/250
# 750/750 [==============================] - 0s 124us/step - loss: 8.9508e-04 - acc: 1.0000 - val_loss: 4.8115e-04 - val_acc: 1.0000
# Epoch 241/250
# 750/750 [==============================] - 0s 150us/step - loss: 8.5773e-04 - acc: 1.0000 - val_loss: 4.6179e-04 - val_acc: 1.0000
# Epoch 242/250
# 750/750 [==============================] - 0s 163us/step - loss: 8.1392e-04 - acc: 1.0000 - val_loss: 4.5146e-04 - val_acc: 1.0000
# Epoch 243/250
# 750/750 [==============================] - 0s 133us/step - loss: 7.9616e-04 - acc: 1.0000 - val_loss: 4.3459e-04 - val_acc: 1.0000
# Epoch 244/250
# 750/750 [==============================] - 0s 115us/step - loss: 7.5986e-04 - acc: 1.0000 - val_loss: 4.1883e-04 - val_acc: 1.0000
# Epoch 245/250
# 750/750 [==============================] - 0s 121us/step - loss: 7.4835e-04 - acc: 1.0000 - val_loss: 4.0833e-04 - val_acc: 1.0000
# Epoch 246/250
# 750/750 [==============================] - 0s 119us/step - loss: 7.3011e-04 - acc: 1.0000 - val_loss: 3.9678e-04 - val_acc: 1.0000
# Epoch 247/250
# 750/750 [==============================] - 0s 121us/step - loss: 6.9060e-04 - acc: 1.0000 - val_loss: 3.8272e-04 - val_acc: 1.0000
# Epoch 248/250
# 750/750 [==============================] - 0s 116us/step - loss: 6.7457e-04 - acc: 1.0000 - val_loss: 3.7426e-04 - val_acc: 1.0000
# Epoch 249/250
# 750/750 [==============================] - 0s 130us/step - loss: 6.7171e-04 - acc: 1.0000 - val_loss: 3.7598e-04 - val_acc: 1.0000
# Epoch 250/250
# 750/750 [==============================] - 0s 120us/step - loss: 6.9202e-04 - acc: 1.0000 - val_loss: 3.5515e-04 - val_acc: 1.0000

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# Notar que se agregaron una keys, asociadas al set de validación. Grafiquemos.

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ¿Cuántos parámetros tiene ahora el modelo?

# %%
print(model.get_weights())
# Out:
# [array([[ 1.4847497 ,  1.4714897 ,  2.4256623 ,  1.7084346 , -2.689887  ,
#         -1.5276732 , -0.8759499 , -0.24335489,  1.4699892 , -1.949462  ],
#        [ 0.06930859, -0.52458483,  0.9676772 ,  0.07158685, -0.14265996,
#          1.4880002 , -1.0468562 ,  0.07198805,  0.60847074, -0.91486174]],
#       dtype=float32), array([-0.811171  , -0.8805387 ,  1.0219686 , -0.94020545, -1.4640975 ,
#        -0.9187826 ,  1.1639881 , -0.42199728,  0.6198277 ,  0.8460927 ],
#       dtype=float32), array([[ 5.8076506 ],
#        [ 5.384447  ],
#        [-2.7228699 ],
#        [ 5.969812  ],
#        [-6.3796873 ],
#        [-2.4191217 ],
#        [ 1.641887  ],
#        [ 0.25487253],
#        [-2.2966816 ],
#        [ 2.3828335 ]], dtype=float32), array([0.4303614], dtype=float32)]

# %% [markdown]
# Y graficamos las fronteras de decisión. ¿Notan que ya no es una frontera abrupta, sino que hay una zona de cambio?¿A qué se debe?

# %%
plt.figure(figsize = (10,6))

ax = sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                      np.linspace(*ylim, num=200))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
contours = ax.contourf(xx, yy, Z, levels = 10, alpha=0.3, cmap = 'plasma')
plt.show()

# %% [markdown]
# **Ejercicio:** volver a correr esta sección, pero reemplazando la función que genera los datos `make_blobs` por `make_moons`. ¿Qué problema ven en el resultado?
#
# **Ejercicio**: con los datos producidos por `make_moons`, agregar una capa a la red neuronal, con 10 neuronas y función de activación `relu`.

# %% [markdown]
# ## 2. MNIST
#
# El dataset de MNIST es un dataset muy conocido. Consiste en dígitos escritos a mano. Muchas modelos de redes neuronales son probados primeros en este set. Pueden encontrar una descripción más detallada, y un ranking de modelos con su desempeño, en el siguiente link.
#
# https://en.wikipedia.org/wiki/MNIST_database
#
# Vamos a arrancar con una sola capa, con una activación `softmax`, ya que se trata de diez clases.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import os #esta libreria permite trabajar con funciones del sistema operativo 
import random

from sklearn.model_selection import train_test_split

# %% [markdown]
# **1. Carga de datos**
#
# Cada instancia del dataset es una imagen guardada en una carpeta con la etiqueta correspondiente.

# %%
directorio = 'Datasets/MNIST/'

# %% [markdown]
# Miramos las carpetas que hay adentro de la carpeta MNIST

# %%
print(os.listdir(directorio))
# Out:
# ['8', '6', '7', '9', '4', '2', '3', '5', '1', '0']

# %% [markdown]
# Creamos los contenedores vacíos

# %%
todas_imagenes = []
y_todas_imagenes = []

# %% [markdown]
# y los llenamos.

# %%
digitos = np.arange(0,10)
for digito in digitos:
    directorio = 'Datasets/MNIST/' + str(digito) + '/'
    print(digito, directorio)
    print('Hay', len(os.listdir(directorio)),'imagenes')
    for imagen in os.listdir(directorio):
        todas_imagenes.append(plt.imread(directorio + imagen))
        y_todas_imagenes.append(digito)
        
todas_imagenes = np.array(todas_imagenes)
y_todas_imagenes = np.array(y_todas_imagenes)
# Out:
# 0 Datasets/MNIST/0/
# Hay 4132 imagenes
# 1 Datasets/MNIST/1/
# Hay 4684 imagenes
# 2 Datasets/MNIST/2/
# Hay 4177 imagenes
# 3 Datasets/MNIST/3/
# Hay 4351 imagenes
# 4 Datasets/MNIST/4/
# Hay 4072 imagenes
# 5 Datasets/MNIST/5/
# Hay 3795 imagenes
# 6 Datasets/MNIST/6/
# Hay 4137 imagenes
# 7 Datasets/MNIST/7/
# Hay 4401 imagenes
# 8 Datasets/MNIST/8/
# Hay 4063 imagenes
# 9 Datasets/MNIST/9/
# Hay 4188 imagenes

# %% [markdown]
# **2. Preprocesado**
#
# **Ejercicio:** Mirar el `shape` de `X` y responder: ¿Cuántas instancias son?¿Qué ancho y largo tienen las imágenes?¿Cuántas bandas?

# %%
print(todas_imagenes.shape, y_todas_imagenes.shape)
n_instancias = todas_imagenes.shape[0]
ancho_imagen = todas_imagenes.shape[1]
largo_imagen = todas_imagenes.shape[2]
# Out:
# (42000, 28, 28) (42000,)

# %% [markdown]
# Miramos una imagen al azar.

# %%
idx_imagen = np.random.randint(0,todas_imagenes.shape[0])
plt.figure(figsize = (6,6))
plt.title('Es un ' + str(y_todas_imagenes[idx_imagen]))
plt.imshow(todas_imagenes[idx_imagen, :, :])
plt.show()

# %% [markdown]
# **Ejercicio:** Crear un arreglo `X` que sea igual a `todas_imagenes`, pero de forma `(n_instancias, largo_imagen * ancho_imagen)`.

# %%
X = todas_imagenes.reshape(n_instancias, largo_imagen*ancho_imagen)
print(X.shape)
# Out:
# (42000, 784)

# %% [markdown]
# **Ejercicio:** Reescalar las imágenes entre 0 y 1.

# %%
X = X/255

# %% [markdown]
# **Ejercicio:** usar el `to_categorical` de Keras para llevar `y_todas_imagenes` a una columna con unos y ceros para cada clase `y` (One Hot Encoding).

# %%
from keras.utils import to_categorical
y =to_categorical(y_todas_imagenes)
print(y.shape)
# Out:
# (42000, 10)

# %% [markdown]
# **Ejercicio:** hacer un `train_test_split`. Usar el 20% del dataset como conjunto de test.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify = y)

# %% [markdown]
# **3. Entrenamiento del modelo**
#
# Comenzar entrenando un Red Neuronal de una capa, con diez neuronas, función de activación `softmax` y pérdida `categorical_crossentropy`. Usar como optimizador `Adam` y `epoch = 20`.

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
import keras

model = Sequential()
#     model.add(Dense(16, activation='relu'))
#     model.add(Dense(8, activation='relu'))
# model.add(Dense(800, activation='relu'))
model.add(Dense(10, activation='softmax'))

optimizador = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer=optimizador,loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Train on 30240 samples, validate on 3360 samples
# Epoch 1/10
# 30240/30240 [==============================] - 3s 108us/step - loss: 0.5843 - acc: 0.8520 - val_loss: 0.3563 - val_acc: 0.9057
# Epoch 2/10
# 30240/30240 [==============================] - 3s 110us/step - loss: 0.3304 - acc: 0.9085 - val_loss: 0.3063 - val_acc: 0.9137
# Epoch 3/10
# 30240/30240 [==============================] - 3s 95us/step - loss: 0.2939 - acc: 0.9173 - val_loss: 0.2949 - val_acc: 0.9152
# Epoch 4/10
# 30240/30240 [==============================] - 3s 106us/step - loss: 0.2761 - acc: 0.9234 - val_loss: 0.2728 - val_acc: 0.9259
# Epoch 5/10
# 30240/30240 [==============================] - 3s 97us/step - loss: 0.2644 - acc: 0.9256 - val_loss: 0.2752 - val_acc: 0.9185
# Epoch 6/10
# 30240/30240 [==============================] - 3s 90us/step - loss: 0.2557 - acc: 0.9286 - val_loss: 0.2626 - val_acc: 0.9262
# Epoch 7/10
# 30240/30240 [==============================] - 3s 108us/step - loss: 0.2489 - acc: 0.9294 - val_loss: 0.2587 - val_acc: 0.9292
# Epoch 8/10
# 30240/30240 [==============================] - 3s 110us/step - loss: 0.2430 - acc: 0.9315 - val_loss: 0.2570 - val_acc: 0.9304
# Epoch 9/10
# 30240/30240 [==============================] - 3s 114us/step - loss: 0.2386 - acc: 0.9332 - val_loss: 0.2572 - val_acc: 0.9286
# Epoch 10/10
# 30240/30240 [==============================] - 3s 110us/step - loss: 0.2346 - acc: 0.9341 - val_loss: 0.2558 - val_acc: 0.9324

# %% [markdown]
# **Ejercicio:** ¿cuántos parámetros tiene el modelo? Recordar que hay una función de Keras que hace un *informe* de la red neuronal.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Ejercicio:** Graficar la pérdida y la exactitud en función de *epochs* para validación y entrenamiento.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.legend(['train', 'test'], loc='upper left')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **4. Evaluación de los resultados.**
#
# **Ejercicio**: predecir las etiquetas de todo el set de testeo.

# %%
y_test_pred = model.predict(X_test)

# %% [markdown]
# Esto sirve para pasar de probabilidades a la etiqueta en sí. En este caso, la etiqueta es el dígito, y corresponde al número de columna.

# %%
y_test_pred = np.argmax(y_test_pred, axis = 1)
y_test_pred.shape
# Out:
# (8400,)

# %% [markdown]
# **Ejercicio:** Calcular exactitud y la matriz de confusión para el conjunto de entrenamiento.

# %%
from sklearn.metrics import confusion_matrix

y_test = np.argmax(y_test,axis = 1)

confusion_matrix(y_test, y_test_pred)
# Out:
# array([[799,   0,   0,   0,   0,  12,   8,   2,   6,   0],
#        [  0, 911,   8,   4,   0,   2,   2,   2,   6,   2],
#        [  7,   8, 747,  11,  11,   5,  11,   7,  22,   6],
#        [  4,   4,  22, 765,   1,  40,   3,   4,  23,   4],
#        [  1,   5,   6,   0, 754,   1,  11,   1,   8,  27],
#        [ 13,   2,   6,  17,   6, 660,  18,   5,  26,   6],
#        [  2,   0,   5,   0,   5,   5, 807,   0,   3,   0],
#        [  1,   7,  14,   1,   8,   3,   1, 797,   3,  45],
#        [  6,  16,   3,  19,   3,  20,   7,   3, 727,   9],
#        [  4,   3,   0,  14,  18,   3,   1,  14,  10, 771]])

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_test_pred)
# Out:
# 0.9211904761904762

# %% [markdown]
# **Ejercicio:** ¿Dónde se está confundiendo? Graficar algunos ejemplos.

# %%
errores = y_test != y_test_pred

# %%
imagenes_errores = X_test[errores,:]
y_test_errores = y_test[errores]
y_test_pred_errores = y_test_pred[errores]
print(imagenes_errores.shape)
# Out:
# (662, 784)

# %%
imagenes_errores = imagenes_errores.reshape(imagenes_errores.shape[0], ancho_imagen, largo_imagen)
print(imagenes_errores.shape)
# Out:
# (662, 28, 28)

# %%
idx_imagen = np.random.randint(0,imagenes_errores.shape[0])
plt.figure(figsize = (6,6))
plt.title('Es un ' + str(y_test_errores[idx_imagen]) +'. Fue etiquetado como ' + str(y_test_pred_errores[idx_imagen]))
plt.imshow(imagenes_errores[idx_imagen, :, :])
plt.show()

# %% [markdown]
# **Ejercicio:** Volver a entrenar, pero agregando una capa con 800 neuronas y función de activación `relu`.

# %% [markdown]
# **Extra:** En el caso del Perceptrón de una sola capa (10 neuronas de salida y nada más), ¿qué está viendo la red?
#
# Notar que los parámetros para cualquiera de las neuronas de salida son 784 + Bias. Como hay 10 neuronas, son 7850 parámetros. Keras, con las función `model.get_weights()`, devuelve todos los pesos y *biases* de cada neurona. Seleccionado la primera componente, descartamos los *biases*.

# %%
ws = model.get_weights()[0]
print(ws.shape)
# Out:
# (784, 10)

# %% [markdown]
# Notar que son 784: un peso por cada pixel de la imagen - sin el bias - por diez neuronas.
#
# Como son 784, podemos llevarlos a la forma `(28,28)` y graficarlos como si fueran una imagen. Hacemos eso para todas las neuronas.

# %%
plt.figure(figsize = (20,10))
for i in range(10):
    plt.subplot(2,5,i+1)
    w0 = ws[:,i]
    plt.title(i)
    plt.imshow(w0.reshape(28,28))
plt.tight_layout()
plt.show()
